# %%
#Librerias para gestionar datos tabulares
import pandas as pd

from datetime import datetime

import warnings

warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)

# %%
df_netflix_original = pd.read_csv("datos/netflix_originals.csv", index_col=0)
df_netflix_titles = pd.read_csv("datos/netflix_titles.csv", index_col= 0)

# %%
df_netflix_original
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language
# ...

# %%
df_netflix_original.describe().T
# Out:
#             count                           mean                  min  \
# Premiere      513  2019-06-16 01:21:24.210526208  2014-12-13 00:00:00
# Runtime     513.0                      94.674464                  4.0
# IMDB Score  513.0                       6.210916                  2.5
#
#                             25%                  50%                  75%  \
# Premiere    2018-06-08 00:00:00  2019-10-18 00:00:00  2020-09-17 00:00:00
# Runtime                    87.0                 97.0                108.0
# IMDB Score                  5.6                  6.3                  6.9
#
#                             max        std
# Premiere    2021-05-27 00:00:00        NaN
# Runtime                   209.0  26.648121
# IMDB Score                  9.0    0.96885

# %%
df_netflix_original.describe(include="O").T
# Out:
#            count unique                                       top freq
# Title        513    513  David Attenborough: A Life on Our Planet    1
# Genre        513    106                               Documentary  132
# Language     513     37                                   English  352
# Mes          513     12                                   October   69
# Ano          513      8                                      2020  164
# Dia_Semana   513      7                                    Friday  346

# %%
df_netflix_titles
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_netflix_titles.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max
# release_year  2021.0

# %%
df_netflix_titles.describe(include="O").T
# Out:
#             count unique                                                top  \
# show_id      8807   8807                                              s8807
# type         8807      2                                              Movie
# title        8807   8807                                             Zubaan
# director     6173   4528                                      Rajiv Chilaka
# cast         7982   7692                                 David Attenborough
# country      7976    748                                      United States
# date_added   8797   1767                                    January 1, 2020
# rating       8803     17                                              TV-MA
# duration     3994    185                                          2 Seasons
# listed_in    8807    514                       Dramas, International Movies
# description  8807   8775  Paranormal activity at a lush, abandoned prope...
#
#              freq
# show_id         1
# ...

# %%
df_netflix_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 513 entries, 0 to 583
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       513 non-null    object
#  1   Genre       513 non-null    object
#  2   Premiere    513 non-null    datetime64[ns]
#  3   Runtime     513 non-null    int64
#  4   IMDB Score  513 non-null    float64
#  5   Language    513 non-null    object
#  6   Originales  513 non-null    bool
#  7   Mes         513 non-null    object
#  8   Ano         513 non-null    object
#  9   Dia_Semana  513 non-null    object
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 40.6+ KB

# %%
df_netflix_original.dtypes
# Out:
# Title          object
# Genre          object
# Premiere       object
# Runtime         int64
# IMDB Score    float64
# Language       object
# dtype: object

# %%
df_netflix_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      3994 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
df_netflix_titles.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_netflix_original.isnull().sum()
# Out:
# Title         0
# Genre         0
# Premiere      0
# Runtime       0
# IMDB Score    0
# Language      0
# dtype: int64

# %%
df_netflix_original.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_netflix_titles.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration        4813
# listed_in          0
# description        0
# dtype: int64

# %%
df_netflix_titles.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_netflix_original['Genre'].unique()
# Out:
# array(['Documentary', 'Thriller', 'Science fiction/Drama',
#        'Horror thriller', 'Mystery', 'Action', 'Comedy',
#        'Heist film/Thriller', 'Musical/Western/Fantasy', 'Drama',
#        'Romantic comedy', 'Action comedy', 'Horror anthology',
#        'Political thriller', 'Superhero-Comedy', 'Horror',
#        'Romance drama', 'Anime / Short', 'Superhero', 'Heist', 'Western',
#        'Animation/Superhero', 'Family film', 'Action-thriller',
#        'Teen comedy-drama', 'Romantic drama', 'Animation',
#        'Aftershow / Interview', 'Science fiction adventure',
#        'Science fiction', 'Comedy-drama', 'Comedy/Fantasy/Family',
#        'Action/Comedy', 'Action/Science fiction',
#        'Romantic teenage drama', 'Comedy / Musical', 'Musical',
#        'Variety show', 'Science fiction/Mystery',
#        'Psychological thriller drama', 'Adventure/Comedy', 'Black comedy',
#        'Romance', 'Horror comedy', 'Christian musical',
# ...

# %%
df_netflix_original['Language'].unique()

idiomas = df_netflix_original['Language'].dropna().tolist()

idiomas_unicos = list(set(idiomas))

idiomas_unicos

#for idioma in idiomas_unicos:
#    for valor in idioma:
#        language = valor.split("/")
#        if language not in idiomas_unicos:
#            idiomas_unicos.append(language)

# idiomas_unicos
# Out:
# ['Polish',
#  'Portuguese',
#  'Malay',
#  'German',
#  'Korean',
#  'English/Russian',
#  'French',
#  'Swedish',
#  'English/Spanish',
#  'English/Japanese',
#  'Thai',
#  'English/Taiwanese/Mandarin',
#  'Spanish/Basque',
#  'Italian',
#  'Spanish/Catalan',
#  'English/Hindi',
#  'Tamil',
#  'Dutch',
#  'Norwegian',
#  'Hindi',
#  'English/Mandarin',
#  'Indonesian',
#  'Thia/English',
#  'Spanish/English',
#  'English/Korean',
#  'English/Akan',
#  'English/Swedish',
#  'English/Arabic',
#  'English/Ukranian/Russian',
#  'Japanese',
#  'Khmer/English/French',
#  'Filipino',
#  'Turkish',
#  'Marathi',
#  'Spanish',
#  'English',
#  'Bengali']

# %%
df_netflix_titles['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df_netflix_original["Originales"] = True

# %%
df_netflix_original
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language  \
# ...

# %%
df_netflix_original.info()

# type(df_netflix_original.Premiere)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 513 entries, 0 to 583
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       513 non-null    object
#  1   Genre       513 non-null    object
#  2   Premiere    513 non-null    object
#  3   Runtime     513 non-null    int64
#  4   IMDB Score  513 non-null    float64
#  5   Language    513 non-null    object
#  6   Originales  513 non-null    bool
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 28.6+ KB

# %%
df_netflix_original.Premiere
# Out:
# 0         August 5, 2019
# 1        August 21, 2020
# 2      December 26, 2019
# 3       January 19, 2018
# 4       October 30, 2020
#              ...
# 576    November 24, 2017
# 577     October 23, 2019
# 580      October 9, 2015
# 581    December 16, 2018
# 583      October 4, 2020
# Name: Premiere, Length: 513, dtype: object

# %%
lista_meses = []

for fecha in df_netflix_original.Premiere:
    mes = fecha.split(' ')[0]
    lista_meses.append(mes)
    print(mes)
# Out:
# August
# August
# December
# January
# October
# November
# December
# June
# March
# May
# November
# September
# October
# November
# December
# January
# February
# January
# August
# July
# August
# February
# April
# July
# April
# July
# February
# December
# May
# October
# February
# October
# July
# July
# November
# January
# March
# April
# October
# December
# December
# January
# May
# October
# January
# April
# December
# April
# August
# November
# October
# January
# July
# October
# July
# February
# October
# January
# April
# April
# February
# July
# August
# July
# July
# February
# May
# February
# May
# October
# May
# May
# April
# May
# February
# September
# November
# April
# November
# August
# April
# August
# May
# September
# April
# June
# April
# August
# October
# December
# May
# March
# March
# October
# April
# August
# January
# November
# July
# December
# October
# December
# April
# October
# November
# February
# April
# February
# February
# ...

# %%
print(lista_meses)
# Out:
# ['August', 'August', 'December', 'January', 'October', 'November', 'December', 'June', 'March', 'May', 'November', 'September', 'October', 'November', 'December', 'January', 'February', 'January', 'August', 'July', 'August', 'February', 'April', 'July', 'April', 'July', 'February', 'December', 'May', 'October', 'February', 'October', 'July', 'July', 'November', 'January', 'March', 'April', 'October', 'December', 'December', 'January', 'May', 'October', 'January', 'April', 'December', 'April', 'August', 'November', 'October', 'January', 'July', 'October', 'July', 'February', 'October', 'January', 'April', 'April', 'February', 'July', 'August', 'July', 'July', 'February', 'May', 'February', 'May', 'October', 'May', 'May', 'April', 'May', 'February', 'September', 'November', 'April', 'November', 'August', 'April', 'August', 'May', 'September', 'April', 'June', 'April', 'August', 'October', 'December', 'May', 'March', 'March', 'October', 'April', 'August', 'January', 'November', 'July', 
# ...

# %%
df_netflix_original["Mes"] = lista_meses
df_netflix_original
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language  \
# ...

# %%
# df_netflix_original["Mes"] = [fecha.split(' ')[0]for fecha in df_netflix_original.Premiere]
# df_netflix_original

# %%
df_netflix_original["Ano"] = [fecha.split(' ')[2]for fecha in df_netflix_original.Premiere]
df_netflix_original
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#               Premiere  Runtime  IMDB Score                  Language  \
# ...

# %%
df_netflix_original['Premiere'] = df_netflix_original['Premiere'].str.replace('.', ',')

# %%
df_netflix_original['Premiere'] = pd.to_datetime(df_netflix_original['Premiere'], format='%B %d, %Y')

# %%
df_netflix_original['Dia_Semana'] = df_netflix_original['Premiere'].dt.day_name()
df_netflix_original
# Out:
#                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 576                       Cuba and the Cameraman            Documentary
# 577                       Dancing with the Birds            Documentary
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 583     David Attenborough: A Life on Our Planet            Documentary
#
#       Premiere  Runtime  IMDB Score                  Language  Originales  \
# ...

# %%
# Mergear dataFrames manteniendo todos los valores de la izda (df_netflix_titles)

df_merge = df_netflix_titles.merge(df_netflix_original, left_on = "title" , right_on="Title", how="left")
df_merge
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_merge.drop("Title", axis = 1, inplace= True)

df_merge
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df_merge.rename(columns={'title': 'Title'}, inplace=True)

# %%
peliculas_por_dia = df_merge['Dia_Semana'].value_counts()

peliculas_por_dia
# Out:
# Dia_Semana
# Friday       346
# Wednesday     70
# Thursday      55
# Tuesday       18
# Monday        13
# Sunday         8
# Saturday       3
# Name: count, dtype: int64

# %%
print(f"Número de titulos originales:{df_merge['Originales'].notnull().sum()}")
# Out:
# Número de titulos originales:513

# %%
total_titlulos = df_netflix_titles['title'].nunique()

print(f"Total títulos: {total_titlulos}")
# Out:
# Total títulos: 8807

# %%
df_merge['IMDB Score'] = df_merge['IMDB Score'].fillna(0)

puntuacion_imdb = df_merge.groupby('Originales')['IMDB Score'].mean()
print(puntuacion_imdb)
# Out:
# Originales
# False    0.000000
# True     6.210916
# Name: IMDB Score, dtype: float64

# %%
n_movies = df_merge.loc[df_merge['type'] == 'Movie'].shape[0]

print(f"El número de películas es: {n_movies}")
print(f"El número de series es: {8807 - n_movies}")
# Out:
# El número de películas es: 6131
# El número de series es: 2676

# %%
series = df_merge.loc[df_merge['type'] == 'TV Show', ['Title', 'duration']]

series
# Out:
#                       Title   duration
# 1             Blood & Water  2 Seasons
# 2                 Ganglands        NaN
# 3     Jailbirds New Orleans        NaN
# 4              Kota Factory  2 Seasons
# 5             Midnight Mass        NaN
# ...                     ...        ...
# 8795        Yu-Gi-Oh! Arc-V  2 Seasons
# 8796             Yunus Emre  2 Seasons
# 8797              Zak Storm        NaN
# 8800     Zindagi Gulzar Hai        NaN
# 8803            Zombie Dumb  2 Seasons
#
# [2676 rows x 2 columns]

# %%
titlulos_EEUU = df_merge.loc[df_merge['country'] == 'United States']

titlulos_EEUU
# Out:
#      show_id     type                 Title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 9        s10    Movie          The Starling   Theodore Melfi
# 15       s16  TV Show     Dear White People              NaN
# 27       s28    Movie             Grown Ups     Dennis Dugan
# 28       s29    Movie            Dark Skies    Scott Stewart
# ...      ...      ...                   ...              ...
# 8791   s8792    Movie           Young Adult    Jason Reitman
# 8793   s8794    Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803    Movie                Zodiac    David Fincher
# 8804   s8805    Movie            Zombieland  Ruben Fleischer
# 8805   s8806    Movie                  Zoom     Peter Hewitt
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...  United States
# ...

# %%
peliculas = df_merge.loc[df_merge['type'] == 'Movie', ['Title', 'director']]

peliculas
# Out:
#                                  Title                       director
# 0                 Dick Johnson Is Dead                Kirsten Johnson
# 6     My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7                              Sankofa                   Haile Gerima
# 9                         The Starling                 Theodore Melfi
# 12                        Je Suis Karl            Christian Schwochow
# ...                                ...                            ...
# 8801                           Zinzana                Majid Al Ansari
# 8802                            Zodiac                  David Fincher
# 8804                        Zombieland                Ruben Fleischer
# 8805                              Zoom                   Peter Hewitt
# 8806                            Zubaan                    Mozez Singh
#
# [6131 rows x 2 columns]

# %%
titulos_2018 = df_merge.loc[df_merge['release_year'] == 2018, ['Title', 'listed_in']]
titulos_2018
# Out:
#                                                   Title  \
# 21                               Resurrection: Ertugrul
# 37                                          Angry Birds
# 73                                         King of Boys
# 94                                            Show Dogs
# 96    If I Leave Here Tomorrow: A Film About Lynyrd ...
# ...                                                 ...
# 8732                                      White Chamber
# 8743                                           Wildlife
# 8774                                          يوم الدين
# 8775                                    Yeh Meri Family
# 8803                                        Zombie Dumb
#
#                                               listed_in
# 21    International TV Shows, TV Action & Adventure,...
# 37                                Kids' TV, TV Comedies
# 73                         Dramas, International Movies
# 94                   Children & Family Movies, Comedies
# ...

# %%
sin_director = df_merge.loc[df_merge['director'].isnull(), 'Title']
sin_director
# Out:
# 1                             Blood & Water
# 3                     Jailbirds New Orleans
# 4                              Kota Factory
# 10      Vendetta: Truth, Lies and The Mafia
# 14          Crime Stories: India Detectives
#                        ...
# 8795                        Yu-Gi-Oh! Arc-V
# 8796                             Yunus Emre
# 8797                              Zak Storm
# 8800                     Zindagi Gulzar Hai
# 8803                            Zombie Dumb
# Name: Title, Length: 2634, dtype: object

# %%
df_merge.iloc[:5][['Title', 'director', 'country']]
# Out:
#                    Title         director        country
# 0   Dick Johnson Is Dead  Kirsten Johnson  United States
# 1          Blood & Water              NaN   South Africa
# 2              Ganglands  Julien Leclercq            NaN
# 3  Jailbirds New Orleans              NaN            NaN
# 4           Kota Factory              NaN          India

# %%
df_merge.iloc[-5:][['Title', 'description']]
# Out:
#             Title                                        description
# 8802       Zodiac  A political cartoonist, a crime reporter and a...
# 8803  Zombie Dumb  While living alone in a spooky town, a young g...
# 8804   Zombieland  Looking to survive in a world taken over by zo...
# 8805         Zoom  Dragged from civilian life, a former superhero...
# 8806       Zubaan  A scrappy but poor boy worms his way into a ty...

# %%
df_merge.iloc[:10, 1:5]
# Out:
#       type                             Title                       director  \
# 0    Movie              Dick Johnson Is Dead                Kirsten Johnson
# 1  TV Show                     Blood & Water                            NaN
# 2  TV Show                         Ganglands                Julien Leclercq
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
# 8  TV Show     The Great British Baking Show                Andy Devonshire
# 9    Movie                      The Starling                 Theodore Melfi
#
#                                                 cast
# 0                                                NaN
# ...

# %%
df_merge.iloc[-7:, [2, 3, 5]]
# Out:
#                    Title         director                       country
# 8800  Zindagi Gulzar Hai              NaN                      Pakistan
# 8801             Zinzana  Majid Al Ansari  United Arab Emirates, Jordan
# 8802              Zodiac    David Fincher                 United States
# 8803         Zombie Dumb              NaN                           NaN
# 8804          Zombieland  Ruben Fleischer                 United States
# 8805                Zoom     Peter Hewitt                 United States
# 8806              Zubaan      Mozez Singh                         India

# %%
df_merge.iloc[14:25, :4]
# Out:
#    show_id     type                                              Title  \
# 14     s15  TV Show                    Crime Stories: India Detectives
# 15     s16  TV Show                                  Dear White People
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 18     s19    Movie                                          Intrusion
# 19     s20  TV Show                                             Jaguar
# 20     s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# 21     s22  TV Show                             Resurrection: Ertugrul
# 22     s23    Movie                                    Avvai Shanmughi
# 23     s24    Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
# 24     s25    Movie                                              Jeans
#
#                                          director
# 14                                            NaN
# ...

# %%
df_merge.iloc[19:30][['Title', 'release_year', 'rating']]
# Out:
#                                               Title  release_year rating
# 19                                           Jaguar          2021  TV-MA
# 20  Monsters Inside: The 24 Faces of Billy Milligan          2021  TV-14
# 21                           Resurrection: Ertugrul          2018  TV-14
# 22                                  Avvai Shanmughi          1996  TV-PG
# 23     Go! Go! Cory Carson: Chrissy Takes the Wheel          2021   TV-Y
# 24                                            Jeans          1998  TV-14
# 25                             Love on the Spectrum          2021  TV-14
# 26                                   Minsara Kanavu          1997  TV-PG
# 27                                        Grown Ups          2010  PG-13
# 28                                       Dark Skies          2013  PG-13
# 29                                         Paranoia          2013  PG-13
